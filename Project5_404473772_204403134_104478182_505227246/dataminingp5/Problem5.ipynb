# %%
from Project5_HelperFeature import extract_feat 
import matplotlib.pyplot as plt

# %%
names = ["tweets_#gohawks.txt", "tweets_#gopatriots.txt", \
         "tweets_#nfl.txt", "tweets_#patriots.txt", "tweets_#sb49.txt", "tweets_#superbowl.txt"]

columns= ['N','NR','SNF','MF','TD','NI','RS','UCF','LC','FOA','target']

feat = ["number of tweets","number of retweets", "sum of followers", "max of followers",\
        "time of day", "number of impressions", "ranking score", "friend count of user", "listed count", "foll. of orig. author"]

# %%
p1 = extract_feat(names[0],flag = 1)

# %%
p2 = extract_feat(names[1],flag = 1)

# %%
p3 = extract_feat(names[2],flag = 1)

# %%
p4 = extract_feat(names[3],flag = 1)

# %%
p5 = extract_feat(names[4],flag = 1)

# %%
p6 = extract_feat(names[5],flag = 1)

# %%
fig, axes = plt.subplots(1,3, sharey=True, figsize = (15,4))
ax1 = p1.plot(x='NR',y='target',c='DarkBlue', marker = "x", kind = "scatter",ax=axes[0])
ax2 = p1.plot(x='LC',y='target',c='DarkBlue',marker = "x",kind = "scatter",ax=axes[1])
ax3 = p1.plot(x='FOA',y='target',c='DarkBlue',marker = "x", kind = "scatter",ax=axes[2])

# %%
fig, axes = plt.subplots(1,3, sharey=True, figsize = (15,4))
ax1 = p2.plot(x='RS',y='target',c='DarkBlue', marker = "x", kind = "scatter",ax=axes[0])
ax2 = p2.plot(x='LC',y='target',c='DarkBlue',marker = "x",kind = "scatter",ax=axes[1])
ax3 = p2.plot(x='FOA',y='target',c='DarkBlue',marker = "x", kind = "scatter",ax=axes[2])

# %%
fig, axes = plt.subplots(1,3, sharey=True, figsize = (15,4))
ax1 = p3.plot(x='N',y='target',c='DarkBlue', marker = "x", kind = "scatter",ax=axes[0])
ax2 = p3.plot(x='RS',y='target',c='DarkBlue',marker = "x",kind = "scatter",ax=axes[1])
ax3 = p3.plot(x='LC',y='target',c='DarkBlue',marker = "x", kind = "scatter",ax=axes[2])

# %%
fig, axes = plt.subplots(1,3, sharey=True, figsize = (15,4))
ax1 = p4.plot(x='RS',y='target',c='DarkBlue', marker = "x", kind = "scatter",ax=axes[0])
ax2 = p4.plot(x='LC',y='target',c='DarkBlue',marker = "x",kind = "scatter",ax=axes[1])
ax3 = p4.plot(x='FOA',y='target',c='DarkBlue',marker = "x", kind = "scatter",ax=axes[2])

# %%
fig, axes = plt.subplots(1,3, sharey=True, figsize = (15,4))
ax1 = p5.plot(x='N',y='target',c='DarkBlue', marker = "x", kind = "scatter",ax=axes[0])
ax2 = p5.plot(x='RS',y='target',c='DarkBlue',marker = "x",kind = "scatter",ax=axes[1])
ax3 = p5.plot(x='UCF',y='target',c='DarkBlue',marker = "x", kind = "scatter",ax=axes[2])

# %%
fig, axes = plt.subplots(1,3, sharey=True, figsize = (15,4))
ax1 = p6.plot(x='SNF',y='target',c='DarkBlue', marker = "x", kind = "scatter",ax=axes[0])
ax2 = p6.plot(x='RS',y='target',c='DarkBlue',marker = "x",kind = "scatter",ax=axes[1])
ax3 = p6.plot(x='LC',y='target',c='DarkBlue',marker = "x", kind = "scatter",ax=axes[2])
